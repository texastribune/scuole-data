# %% [markdown]
# <h1>Cleaning the cohorts data</h1>
# <p>This is a notebook that will take the four spreadsheets for the cohorts years and takes out asterisk and formats the columns</p>

# %%
import pandas as pd
import os.path
from pandas.api.types import is_string_dtype
pd.set_option('display.max_columns', None)

# %%
school_year = '2012'

files = [
  "regionState.csv",
  "countyGender.csv",
  "countyEthnicity.csv", 
  "countyEcon.csv"
]

cols_list_asterisk = ['enrolled_8th',
 'enrolled_9th',
 'enrolled_9th_percent',
 'enrolled_10th',
 'enrolled_10th_percent',
 'lessthan_10th_enrolled',
 'lessthan_10th_enrolled_percent',
 'graduated',
 'graduated_percent',
 'enrolled_4yr',
 'enrolled_4yr_percent',
 'enrolled_2yr',
 'enrolled_2yr_percent',
 'total_enrolled',
 'total_enrolled_percent',
 'enrolled_wo_record',
 'enrolled_wo_record_percent',
 'total_degrees',
 'total_degrees_percent',]

cols_to_round = ['enrolled_8th', 'enrolled_9th','enrolled_10th', 'graduated','total_enrolled']

# %%
path_test = "./cohorts/" + school_year + "/countyGender.csv"

path_test2 = "./cohorts/" + school_year + "/regionState.csv"

# %%
data_test2 = pd.read_csv(path_test2)

# %%
data_test = pd.read_csv(path_test)

# %%
data_test.dtypes
# Out:
# Region Code                         int64
# TEA Region                         object
# County Number                       int64
# County Name                        object
# gender                             object
# enrolled_8th                      float64
# enrolled_9th                      float64
# enrolled_9th_percent               object
# enrolled_10th                     float64
# enrolled_10th_percent              object
# lessthan_10th_enrolled             object
# lessthan_10th_enrolled_percent     object
# graduated                         float64
# graduated_percent                  object
# enrolled_4yr                       object
# enrolled_4yr_percent               object
# enrolled_2yr                       object
# enrolled_2yr_percent               object
# total_enrolled                    float64
# total_enrolled_percent             object
# enrolled_wo_record                 object
# enrolled_wo_record_percent         object
# total_degrees                      object
# total_degrees_percent              object
# dtype: object

# %%
asterisk = data_test[data_test['enrolled_wo_record'] == '*']

# %%
asterisk
# Out:
#      Region Code   TEA Region  County Number County Name  gender  \
# 4              1     Edinburg            124    JIM HOGG  Female
# 5              1     Edinburg            124    JIM HOGG    Male
# 10             1     Edinburg            245     WILLACY  Female
# 11             1     Edinburg            245     WILLACY    Male
# 12             1     Edinburg            253      ZAPATA  Female
# ..           ...          ...            ...         ...     ...
# 499           20  San Antonio            142    LA SALLE    Male
# 503           20  San Antonio            163      MEDINA    Male
# 507           20  San Antonio            232      UVALDE    Male
# 510           20  San Antonio            254      ZAVALA  Female
# 511           20  San Antonio            254      ZAVALA    Male
#
#      enrolled_8th  enrolled_9th enrolled_9th_percent  enrolled_10th  \
# 4            44.0          43.0                  98%           37.0
# 5            39.0          39.0                 100%           34.0
# 10          140.0         135.0                  96%          130.0
# 11          161.0         153.0                  95%          145.0
# 12          130.0         128.0                  98%          127.0
# ..            ...           ...                  ...            ...
# 499          49.0          49.0                 100%           42.0
# 503         341.0         325.0                  95%          303.0
# 507         222.0         211.0                  95%          162.0
# 510          90.0          89.0                  99%           83.0
# 511          96.0          93.0                  97%           80.0
#
#     enrolled_10th_percent lessthan_10th_enrolled  \
# 4                     84%                      5
# 5                     87%                      *
# 10                    93%                      6
# 11                    90%                     13
# 12                    98%                      *
# ..                    ...                    ...
# 499                   86%                      6
# 503                   89%                     13
# 507                   73%                     38
# 510                   92%                      *
# 511                   83%                      5
#
#     lessthan_10th_enrolled_percent  graduated graduated_percent enrolled_4yr  \
# 4                              11%       35.0               80%            9
# 5                                *       33.0               85%           12
# 10                              4%      112.0               80%           37
# 11                              8%      134.0               83%           30
# 12                               *      116.0               89%           31
# ..                             ...        ...               ...          ...
# 499                            12%       39.0               80%            *
# 503                             4%      283.0               83%           75
# 507                            17%      146.0               66%           24
# 510                              *       75.0               83%            6
# 511                             5%       74.0               77%            8
#
#     enrolled_4yr_percent enrolled_2yr enrolled_2yr_percent  total_enrolled  \
# 4                    20%           12                  27%            21.0
# 5                    31%           13                  33%            25.0
# 10                   26%           36                  26%            73.0
# 11                   19%           57                  35%            87.0
# 12                   24%           36                  28%            67.0
# ..                   ...          ...                  ...             ...
# 499                    *           13                  27%            16.0
# 503                  22%           83                  24%           158.0
# 507                  11%           78                  35%           102.0
# 510                   7%           47                  52%            53.0
# 511                   8%           36                  38%            44.0
#
#     total_enrolled_percent enrolled_wo_record enrolled_wo_record_percent  \
# 4                      48%                  *                          *
# 5                      64%                  *                          *
# 10                     52%                  *                          *
# 11                     54%                  *                          *
# 12                     52%                  *                          *
# ..                     ...                ...                        ...
# 499                    33%                  *                          *
# 503                    46%                  *                          *
# 507                    46%                  *                          *
# 510                    59%                  *                          *
# 511                    46%                  *                          *
#
#     total_degrees total_degrees_percent
# 4               7                   16%
# 5               6                   15%
# 10             32                   23%
# 11             34                   21%
# 12             36                   28%
# ..            ...                   ...
# 499             7                   14%
# 503            74                   22%
# 507            47                   21%
# 510            27                   30%
# 511            16                   17%
#
# [322 rows x 24 columns]

# %%
na_values = data_test[data_test['graduated_percent'] == 'NA']

# %%
na_values
# Out:
# Empty DataFrame
# Columns: [Region Code, TEA Region, County Number, County Name, gender, enrolled_8th, enrolled_9th, enrolled_9th_percent, enrolled_10th, enrolled_10th_percent, lessthan_10th_enrolled, lessthan_10th_enrolled_percent, graduated, graduated_percent, enrolled_4yr, enrolled_4yr_percent, enrolled_2yr, enrolled_2yr_percent, total_enrolled, total_enrolled_percent, enrolled_wo_record, enrolled_wo_record_percent, total_degrees, total_degrees_percent]
# Index: []

# %%
bell_county = data_test[data_test['County Name'] == 'BELL']

# %%
bell_county
# Out:
#      Region Code TEA Region  County Number County Name  gender  enrolled_8th  \
# 232           12       Waco             14        BELL  Female        2198.0
# 233           12       Waco             14        BELL    Male        2331.0
# 258           13     Austin             14        BELL  Female           NaN
# 259           13     Austin             14        BELL    Male           NaN
#
#      enrolled_9th enrolled_9th_percent  enrolled_10th enrolled_10th_percent  \
# 232        1995.0                  91%         1678.0                   76%
# 233        2070.0                  89%         1658.0                   71%
# 258           NaN                  NaN            NaN                   NaN
# 259           NaN                  NaN            NaN                   NaN
#
#     lessthan_10th_enrolled lessthan_10th_enrolled_percent  graduated  \
# 232                    209                            10%     1648.0
# 233                    307                            13%     1643.0
# 258                    NaN                            NaN        NaN
# 259                    NaN                            NaN        NaN
#
#     graduated_percent enrolled_4yr enrolled_4yr_percent enrolled_2yr  \
# 232               75%          464                  21%          728
# 233               70%          340                  15%          655
# 258               NaN          NaN                  NaN          NaN
# 259               NaN          NaN                  NaN          NaN
#
#     enrolled_2yr_percent  total_enrolled total_enrolled_percent  \
# 232                  33%          1192.0                    54%
# 233                  28%           995.0                    43%
# 258                  NaN             NaN                    NaN
# 259                  NaN             NaN                    NaN
#
#     enrolled_wo_record enrolled_wo_record_percent total_degrees  \
# 232                 81                         4%           476
# 233                 61                         3%           339
# 258                NaN                        NaN           NaN
# 259                NaN                        NaN           NaN
#
#     total_degrees_percent
# 232                   22%
# 233                   15%
# 258                   NaN
# 259                   NaN

# %%
cols_to_round = ['enrolled_8th', 'enrolled_9th','enrolled_10th', 'graduated','total_enrolled']

# %%
# Turn all files
bell_county[cols_to_round] = bell_county[cols_to_round].astype(pd.Int64Dtype())
# Out:
# /var/folders/jm/b21wy2rd66j9kdck8xdkk0p00000gp/T/ipykernel_90310/4261011714.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bell_county[cols_to_round] = bell_county[cols_to_round].astype(pd.Int64Dtype())

# %%
bell_county
# Out:
#      Region Code TEA Region  County Number County Name  gender  enrolled_8th  \
# 232           12       Waco             14        BELL  Female          2198
# 233           12       Waco             14        BELL    Male          2331
# 258           13     Austin             14        BELL  Female          <NA>
# 259           13     Austin             14        BELL    Male          <NA>
#
#      enrolled_9th enrolled_9th_percent  enrolled_10th enrolled_10th_percent  \
# 232          1995                  91%           1678                   76%
# 233          2070                  89%           1658                   71%
# 258          <NA>                  NaN           <NA>                   NaN
# 259          <NA>                  NaN           <NA>                   NaN
#
#     lessthan_10th_enrolled lessthan_10th_enrolled_percent  graduated  \
# 232                    209                            10%       1648
# 233                    307                            13%       1643
# 258                    NaN                            NaN       <NA>
# 259                    NaN                            NaN       <NA>
#
#     graduated_percent enrolled_4yr enrolled_4yr_percent enrolled_2yr  \
# 232               75%          464                  21%          728
# 233               70%          340                  15%          655
# 258               NaN          NaN                  NaN          NaN
# 259               NaN          NaN                  NaN          NaN
#
#     enrolled_2yr_percent  total_enrolled total_enrolled_percent  \
# 232                  33%            1192                    54%
# 233                  28%             995                    43%
# 258                  NaN            <NA>                    NaN
# 259                  NaN            <NA>                    NaN
#
#     enrolled_wo_record enrolled_wo_record_percent total_degrees  \
# 232                 81                         4%           476
# 233                 61                         3%           339
# 258                NaN                        NaN           NaN
# 259                NaN                        NaN           NaN
#
#     total_degrees_percent
# 232                   22%
# 233                   15%
# 258                   NaN
# 259                   NaN

# %%
bell_county.to_csv("./cohorts/" + school_year + "/Bell_County_test.csv", index = False)

# %%
asterisk.head(5)
# Out:
#     Region Code TEA Region  County Number County Name  gender  enrolled_8th  \
# 4             1   Edinburg            124    JIM HOGG  Female          44.0
# 5             1   Edinburg            124    JIM HOGG    Male          39.0
# 10            1   Edinburg            245     WILLACY  Female         140.0
# 11            1   Edinburg            245     WILLACY    Male         161.0
# 12            1   Edinburg            253      ZAPATA  Female         130.0
#
#     enrolled_9th enrolled_9th_percent  enrolled_10th enrolled_10th_percent  \
# 4           43.0                  98%           37.0                   84%
# 5           39.0                 100%           34.0                   87%
# 10         135.0                  96%          130.0                   93%
# 11         153.0                  95%          145.0                   90%
# 12         128.0                  98%          127.0                   98%
#
#    lessthan_10th_enrolled lessthan_10th_enrolled_percent  graduated  \
# 4                       5                            11%       35.0
# 5                       *                              *       33.0
# 10                      6                             4%      112.0
# 11                     13                             8%      134.0
# 12                      *                              *      116.0
#
#    graduated_percent enrolled_4yr enrolled_4yr_percent enrolled_2yr  \
# 4                80%            9                  20%           12
# 5                85%           12                  31%           13
# 10               80%           37                  26%           36
# 11               83%           30                  19%           57
# 12               89%           31                  24%           36
#
#    enrolled_2yr_percent  total_enrolled total_enrolled_percent  \
# 4                   27%            21.0                    48%
# 5                   33%            25.0                    64%
# 10                  26%            73.0                    52%
# 11                  35%            87.0                    54%
# 12                  28%            67.0                    52%
#
#    enrolled_wo_record enrolled_wo_record_percent total_degrees  \
# 4                   *                          *             7
# 5                   *                          *             6
# 10                  *                          *            32
# 11                  *                          *            34
# 12                  *                          *            36
#
#    total_degrees_percent
# 4                    16%
# 5                    15%
# 10                   23%
# 11                   21%
# 12                   28%

# %%
list(asterisk.columns)
# Out:
# ['Region Code',
#  'TEA Region',
#  'County Number',
#  'County Name',
#  'gender',
#  'enrolled_8th',
#  'enrolled_9th',
#  'enrolled_9th_percent',
#  'enrolled_10th',
#  'enrolled_10th_percent',
#  'lessthan_10th_enrolled',
#  'lessthan_10th_enrolled_percent',
#  'graduated',
#  'graduated_percent',
#  'enrolled_4yr',
#  'enrolled_4yr_percent',
#  'enrolled_2yr',
#  'enrolled_2yr_percent',
#  'total_enrolled',
#  'total_enrolled_percent',
#  'enrolled_wo_record',
#  'enrolled_wo_record_percent',
#  'total_degrees',
#  'total_degrees_percent']

# %%
#d = {col : {"*":""} for col in col_list}

# %%
col_list = ['enrolled_8th',
 'enrolled_9th',
 'enrolled_9th_percent',
 'enrolled_10th',
 'enrolled_10th_percent',
 'lessthan_10th_enrolled',
 'lessthan_10th_enrolled_percent',
 'graduated',
 'graduated_percent',
 'enrolled_4yr',
 'enrolled_4yr_percent',
 'enrolled_2yr',
 'enrolled_2yr_percent',
 'total_enrolled',
 'total_enrolled_percent',
 'enrolled_wo_record',
 'enrolled_wo_record_percent',
 'total_degrees',
 'total_degrees_percent']

# %%
#asterisk.replace(to_replace=d, inplace=True)

# %%
asterisk.head(5)
# Out:
#     Region Code TEA Region  County Number County Name  gender  enrolled_8th  \
# 4             1   Edinburg            124    JIM HOGG  Female          44.0
# 5             1   Edinburg            124    JIM HOGG    Male          39.0
# 10            1   Edinburg            245     WILLACY  Female         140.0
# 11            1   Edinburg            245     WILLACY    Male         161.0
# 12            1   Edinburg            253      ZAPATA  Female         130.0
#
#     enrolled_9th enrolled_9th_percent  enrolled_10th enrolled_10th_percent  \
# 4           43.0                  98%           37.0                   84%
# 5           39.0                 100%           34.0                   87%
# 10         135.0                  96%          130.0                   93%
# 11         153.0                  95%          145.0                   90%
# 12         128.0                  98%          127.0                   98%
#
#    lessthan_10th_enrolled lessthan_10th_enrolled_percent  graduated  \
# 4                       5                            11%       35.0
# 5                       *                              *       33.0
# 10                      6                             4%      112.0
# 11                     13                             8%      134.0
# 12                      *                              *      116.0
#
#    graduated_percent enrolled_4yr enrolled_4yr_percent enrolled_2yr  \
# 4                80%            9                  20%           12
# 5                85%           12                  31%           13
# 10               80%           37                  26%           36
# 11               83%           30                  19%           57
# 12               89%           31                  24%           36
#
#    enrolled_2yr_percent  total_enrolled total_enrolled_percent  \
# 4                   27%            21.0                    48%
# 5                   33%            25.0                    64%
# 10                  26%            73.0                    52%
# 11                  35%            87.0                    54%
# 12                  28%            67.0                    52%
#
#    enrolled_wo_record enrolled_wo_record_percent total_degrees  \
# 4                   *                          *             7
# 5                   *                          *             6
# 10                  *                          *            32
# 11                  *                          *            34
# 12                  *                          *            36
#
#    total_degrees_percent
# 4                    16%
# 5                    15%
# 10                   23%
# 11                   21%
# 12                   28%

# %%
asterisk_loop_test = asterisk

# %%
asterisk_loop_test
# Out:
#      Region Code   TEA Region  County Number County Name  gender  \
# 4              1     Edinburg            124    JIM HOGG  Female
# 5              1     Edinburg            124    JIM HOGG    Male
# 10             1     Edinburg            245     WILLACY  Female
# 11             1     Edinburg            245     WILLACY    Male
# 12             1     Edinburg            253      ZAPATA  Female
# ..           ...          ...            ...         ...     ...
# 499           20  San Antonio            142    LA SALLE    Male
# 503           20  San Antonio            163      MEDINA    Male
# 507           20  San Antonio            232      UVALDE    Male
# 510           20  San Antonio            254      ZAVALA  Female
# 511           20  San Antonio            254      ZAVALA    Male
#
#      enrolled_8th  enrolled_9th enrolled_9th_percent  enrolled_10th  \
# 4            44.0          43.0                  98%           37.0
# 5            39.0          39.0                 100%           34.0
# 10          140.0         135.0                  96%          130.0
# 11          161.0         153.0                  95%          145.0
# 12          130.0         128.0                  98%          127.0
# ..            ...           ...                  ...            ...
# 499          49.0          49.0                 100%           42.0
# 503         341.0         325.0                  95%          303.0
# 507         222.0         211.0                  95%          162.0
# 510          90.0          89.0                  99%           83.0
# 511          96.0          93.0                  97%           80.0
#
#     enrolled_10th_percent lessthan_10th_enrolled  \
# 4                     84%                      5
# 5                     87%                      *
# 10                    93%                      6
# 11                    90%                     13
# 12                    98%                      *
# ..                    ...                    ...
# 499                   86%                      6
# 503                   89%                     13
# 507                   73%                     38
# 510                   92%                      *
# 511                   83%                      5
#
#     lessthan_10th_enrolled_percent  graduated graduated_percent enrolled_4yr  \
# 4                              11%       35.0               80%            9
# 5                                *       33.0               85%           12
# 10                              4%      112.0               80%           37
# 11                              8%      134.0               83%           30
# 12                               *      116.0               89%           31
# ..                             ...        ...               ...          ...
# 499                            12%       39.0               80%            *
# 503                             4%      283.0               83%           75
# 507                            17%      146.0               66%           24
# 510                              *       75.0               83%            6
# 511                             5%       74.0               77%            8
#
#     enrolled_4yr_percent enrolled_2yr enrolled_2yr_percent  total_enrolled  \
# 4                    20%           12                  27%            21.0
# 5                    31%           13                  33%            25.0
# 10                   26%           36                  26%            73.0
# 11                   19%           57                  35%            87.0
# 12                   24%           36                  28%            67.0
# ..                   ...          ...                  ...             ...
# 499                    *           13                  27%            16.0
# 503                  22%           83                  24%           158.0
# 507                  11%           78                  35%           102.0
# 510                   7%           47                  52%            53.0
# 511                   8%           36                  38%            44.0
#
#     total_enrolled_percent enrolled_wo_record enrolled_wo_record_percent  \
# 4                      48%                  *                          *
# 5                      64%                  *                          *
# 10                     52%                  *                          *
# 11                     54%                  *                          *
# 12                     52%                  *                          *
# ..                     ...                ...                        ...
# 499                    33%                  *                          *
# 503                    46%                  *                          *
# 507                    46%                  *                          *
# 510                    59%                  *                          *
# 511                    46%                  *                          *
#
#     total_degrees total_degrees_percent
# 4               7                   16%
# 5               6                   15%
# 10             32                   23%
# 11             34                   21%
# 12             36                   28%
# ..            ...                   ...
# 499             7                   14%
# 503            74                   22%
# 507            47                   21%
# 510            27                   30%
# 511            16                   17%
#
# [322 rows x 24 columns]

# %%
for column in cols_list_asterisk:
    if is_string_dtype(data_test[column]):
        data_test[column] = data_test[column].apply(lambda x: str(x).replace("*",'').replace("nan",''))
    else:
        data_test[column] = data_test[column].astype(pd.Int64Dtype())

data_test
    #asterisk_loop_test[column] = asterisk_loop_test[column].apply(lambda x: str(x).replace("'", ''))
# Out:
#      Region Code   TEA Region  County Number County Name  gender  \
# 0              1     Edinburg             31     CAMERON  Female
# 1              1     Edinburg             31     CAMERON    Male
# 2              1     Edinburg            108     HIDALGO  Female
# 3              1     Edinburg            108     HIDALGO    Male
# 4              1     Edinburg            124    JIM HOGG  Female
# ..           ...          ...            ...         ...     ...
# 507           20  San Antonio            232      UVALDE    Male
# 508           20  San Antonio            247      WILSON  Female
# 509           20  San Antonio            247      WILSON    Male
# 510           20  San Antonio            254      ZAVALA  Female
# 511           20  San Antonio            254      ZAVALA    Male
#
#      enrolled_8th  enrolled_9th enrolled_9th_percent  enrolled_10th  \
# 0            3588          3430                  96%           3072
# 1            3811          3641                  96%           3143
# 2            7358          7092                  96%           6291
# 3            7697          7439                  97%           6296
# 4              44            43                  98%             37
# ..            ...           ...                  ...            ...
# 507           222           211                  95%            162
# 508           291           278                  96%            266
# 509           330           318                  96%            302
# 510            90            89                  99%             83
# 511            96            93                  97%             80
#
#     enrolled_10th_percent lessthan_10th_enrolled  \
# 0                     86%                    317
# 1                     82%                    453
# 2                     86%                    690
# 3                     82%                   1015
# 4                     84%                      5
# ..                    ...                    ...
# 507                   73%                     38
# 508                   91%
# 509                   92%                     16
# 510                   92%
# 511                   83%                      5
#
#     lessthan_10th_enrolled_percent  graduated graduated_percent enrolled_4yr  \
# 0                               9%       3053               85%          966
# 1                              12%       3120               82%          850
# 2                               9%       6330               86%         2046
# 3                              13%       6312               82%         1598
# 4                              11%         35               80%            9
# ..                             ...        ...               ...          ...
# 507                            17%        146               66%           24
# 508                                       254               87%           82
# 509                             5%        283               86%           63
# 510                                        75               83%            6
# 511                             5%         74               77%            8
#
#     enrolled_4yr_percent enrolled_2yr enrolled_2yr_percent  total_enrolled  \
# 0                    27%         1114                  31%            2080
# 1                    22%         1030                  27%            1880
# 2                    28%         2136                  29%            4182
# 3                    21%         2116                  27%            3714
# 4                    20%           12                  27%              21
# ..                   ...          ...                  ...             ...
# 507                  11%           78                  35%             102
# 508                  28%           97                  33%             179
# 509                  19%           79                  24%             142
# 510                   7%           47                  52%              53
# 511                   8%           36                  38%              44
#
#     total_enrolled_percent enrolled_wo_record enrolled_wo_record_percent  \
# 0                      58%                 60                         2%
# 1                      49%                 54                         1%
# 2                      57%                 81                         1%
# 3                      48%                 86                         1%
# 4                      48%
# ..                     ...                ...                        ...
# 507                    46%
# 508                    62%                  6                         2%
# 509                    43%                  5                         2%
# 510                    59%
# 511                    46%
#
#     total_degrees total_degrees_percent
# 0             934                   26%
# 1             696                   18%
# 2            1963                   27%
# 3            1285                   17%
# 4               7                   16%
# ..            ...                   ...
# 507            47                   21%
# 508           102                   35%
# 509            64                   19%
# 510            27                   30%
# 511            16                   17%
#
# [512 rows x 24 columns]

# %%
data_test.to_csv("./cohorts/" + school_year + "/all_data_test_2.csv", index = False)

# %%
print("Loop starting...\nFILE | [COLUMNS] ... to edit")


for file in files:
    path = "./cohorts/" + school_year + "/" + file
    
    if os.path.exists(path):
        data = pd.read_csv(path)

        # see if the data has any of the columns we're looking for
        s = pd.Series(cols_list_asterisk).isin(data.columns)
        indexes = list(s[s].index)
        columns_to_edit = [cols_list_asterisk[i] for i in indexes]

        print(file, ":", columns_to_edit)
        
        # Goes through all of the columns we have to edit  
        if len(columns_to_edit) > 0:
            for column in columns_to_edit:
                # if column is string, replaces * and nan with empty string
                if is_string_dtype(data_test[column]):
                    data_test[column] = data_test[column].apply(lambda x: str(x).replace("*",'').replace("nan",''))
                # if column is integer, rounds the number to a whole number and turns NAs into null values
                else:
                    data_test[column] = data_test[column].astype(pd.Int64Dtype())
            data.to_csv(path, index = False)

print("Loop ended successfully!")
# Out:
# Loop starting...
# FILE | [COLUMNS] ... to edit
# regionState.csv : ['enrolled_8th', 'enrolled_9th', 'enrolled_9th_percent', 'enrolled_10th', 'enrolled_10th_percent', 'lessthan_10th_enrolled', 'lessthan_10th_enrolled_percent', 'graduated', 'graduated_percent', 'enrolled_4yr', 'enrolled_4yr_percent', 'enrolled_2yr', 'enrolled_2yr_percent', 'total_enrolled', 'total_enrolled_percent', 'enrolled_wo_record', 'total_degrees', 'total_degrees_percent']
# countyGender.csv : ['enrolled_8th', 'enrolled_9th', 'enrolled_9th_percent', 'enrolled_10th', 'enrolled_10th_percent', 'lessthan_10th_enrolled', 'lessthan_10th_enrolled_percent', 'graduated', 'graduated_percent', 'enrolled_4yr', 'enrolled_4yr_percent', 'enrolled_2yr', 'enrolled_2yr_percent', 'total_enrolled', 'total_enrolled_percent', 'enrolled_wo_record', 'enrolled_wo_record_percent', 'total_degrees', 'total_degrees_percent']
# countyEthnicity.csv : ['enrolled_8th', 'enrolled_9th', 'enrolled_9th_percent', 'enrolled_10th', 'enrolled_10th_percent', 'lessthan_10th_enrolled', 'lessthan_10th_enrolled_percent', 'graduated', 'graduated_percent', 'enrolled_4yr', 'enrolled_4yr_percent', 'enrolled_2yr', 'enrolled_2yr_percent', 'total_enrolled', 'total_enrolled_percent', 'enrolled_wo_record', 'enrolled_wo_record_percent', 'total_degrees', 'total_degrees_percent']
# countyEcon.csv : ['enrolled_8th', 'enrolled_9th', 'enrolled_9th_percent', 'enrolled_10th', 'enrolled_10th_percent', 'lessthan_10th_enrolled', 'lessthan_10th_enrolled_percent', 'graduated', 'graduated_percent', 'enrolled_4yr', 'enrolled_4yr_percent', 'enrolled_2yr', 'enrolled_2yr_percent', 'total_enrolled', 'total_enrolled_percent', 'enrolled_wo_record', 'total_degrees', 'total_degrees_percent']
# Loop ended successfully!
